# %%
from NeuralNetwork import DrivingNeuralNetwork
import os

# %%
model = DrivingNeuralNetwork()
dir = "C:\\Users\\kevin\\OneDrive\\Bureau\\RallyRobotPilot_2025\\scripts\\train_data"
print(f"[INIT] Starting Neural Network Autopilot")
files = [
    os.path.join(dir,f)
    for f in os.listdir(dir)
    if f.endswith(".npz")
]
model.train_model(
    files,
    learning_rate=0.0005,
    epochs=30,
    batch_size=64
)
# Out:
# [INIT] Starting Neural Network Autopilot
#
# Loading 3 files...
#   Loading C:\Users\kevin\OneDrive\Bureau\RallyRobotPilot_2025\scripts\train_data\record_0.npz...
# package_folder: C:\Users\kevin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ursina
# asset_folder: C:\Users\kevin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages
#   Loading C:\Users\kevin\OneDrive\Bureau\RallyRobotPilot_2025\scripts\train_data\record_1.npz...
#   Loading C:\Users\kevin\OneDrive\Bureau\RallyRobotPilot_2025\scripts\train_data\record_3.npz...
#   Total records loaded: 2228
#   Valid samples created: 2227
#   Reward stats: min=-82.35, max=100.00, mean=77.73
# Epoch [1/30], Train Loss: 1.0849, Val Loss: 0.6102
# Epoch [2/30], Train Loss: 0.6215, Val Loss: 0.5396
# Epoch [3/30], Train Loss: 0.5566, Val Loss: 0.5008
# Epoch [4/30], Train Loss: 0.5345, Val Loss: 0.4925
# Epoch [5/30], Train Loss: 0.5193, Val Loss: 0.4874
# Epoch [6/30], Train Loss: 0.5123, Val Loss: 0.4745
# Epoch [7/30], Train Loss: 0.5129, Val Loss: 0.4684
# Epoch [8/30], Train Loss: 0.5047, Val Loss: 0.4724
# Epoch [9/30], Train Loss: 0.5007, Val Loss: 0.4670
# Epoch [10/30], Train Loss: 0.4967, Val Loss: 0.4619
# Epoch [11/30], Train Loss: 0.4918, Val Loss: 0.4641
# Epoch [12/30], Train Loss: 0.4914, Val Loss: 0.4617
# Epoch [13/30], Train Loss: 0.4826, Val Loss: 0.4609
# Epoch [14/30], Train Loss: 0.4803, Val Loss: 0.4578
# Epoch [15/30], Train Loss: 0.4789, Val Loss: 0.4583
# Epoch [16/30], Train Loss: 0.4775, Val Loss: 0.4602
# Epoch [17/30], Train Loss: 0.4793, Val Loss: 0.4554
# Epoch [18/30], Train Loss: 0.4711, Val Loss: 0.4544
# Epoch [19/30], Train Loss: 0.4730, Val Loss: 0.4612
# Epoch [20/30], Train Loss: 0.4681, Val Loss: 0.4504
# Epoch [21/30], Train Loss: 0.4685, Val Loss: 0.4535
# Epoch [22/30], Train Loss: 0.4656, Val Loss: 0.4551
# Epoch [23/30], Train Loss: 0.4656, Val Loss: 0.4468
# Epoch [24/30], Train Loss: 0.4632, Val Loss: 0.4501
# Epoch [25/30], Train Loss: 0.4631, Val Loss: 0.4521
# Epoch [26/30], Train Loss: 0.4644, Val Loss: 0.4504
# Epoch [27/30], Train Loss: 0.4650, Val Loss: 0.4531
# Epoch [28/30], Train Loss: 0.4674, Val Loss: 0.4533
# Epoch [29/30], Train Loss: 0.4635, Val Loss: 0.4512
# Epoch [30/30], Train Loss: 0.4610, Val Loss: 0.4461
# ([1.0849376225471496,
#   0.6215073227882385,
#   0.5566311883926391,
#   0.5344986009597779,
#   0.5193390595912933,
#   0.5122831332683563,
#   0.5129016625881195,
#   0.5047455418109894,
#   0.5006783151626587,
#   0.4966623294353485,
#   0.49181621909141543,
#   0.4913800036907196,
#   0.48263126373291015,
#   0.4802705645561218,
#   0.4788605344295502,
#   0.47749709725379946,
#   0.4793099844455719,
#   0.4711045563220978,
#   0.47299408793449405,
#   0.4680618178844452,
#   0.4684663140773773,
#   0.4655518317222595,
#   0.46563261866569516,
#   0.46323704957962036,
#   0.463105776309967,
#   0.46443968415260317,
#   0.4650220930576324,
#   0.467405788898468,
#   0.4635261690616608,
#   0.46104139924049375],
#  [0.6102464646100998,
#   0.5396489500999451,
#   0.5008134891589483,
#   0.49248869717121124,
#   0.4874209215243657,
#   0.4745086779197057,
#   0.46844521661599475,
#   0.4724409182866414,
#   0.46697600185871124,
#   0.4618737151225408,
#   0.4641474336385727,
#   0.4616565058628718,
#   0.46089450021584827,
#   0.4577864905198415,
#   0.45825471977392834,
#   0.46015559633572894,
#   0.45542965332667035,
#   0.45436201492945355,
#   0.46120726068814594,
#   0.45040274659792584,
#   0.4535082330306371,
#   0.45508354902267456,
#   0.4467516988515854,
#   0.4501392642656962,
#   0.452059472600619,
#   0.45042066772778827,
#   0.45308513442675274,
#   0.45332727829615277,
#   0.451191246509552,
#   0.44614173471927643])

# %%
import numpy
import pickle
import lzma

with lzma.open("record_0.npz", "rb") as file:
    data = pickle.load(file)

        print("Read", len(data), "train_data")
        print(data[0].image)
        print([e for e in data])
# Out:
#   Cell In[3], line 8
#     print("Read", len(data), "train_data")
#     ^
# IndentationError: unexpected indent
